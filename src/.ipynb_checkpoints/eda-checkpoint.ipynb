# %%
# Imports
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# Read data
df_aisles = pd.read_csv("../data/aisles.csv")
df_departments = pd.read_csv("../data/departments.csv")
df_orders = pd.read_csv("../data/orders.csv")
df_products = pd.read_csv("../data/products.csv")
df_order_products_train = pd.read_csv("../data/order_products__train.csv")
df_order_products_prior = pd.read_csv("../data/order_products__prior.csv")

# %%
# Peeking into dataframes
df_aisles.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
# Peeking into dataframes
df_departments.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
# Peeking into dataframes
df_orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Peeking into dataframes
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
df_order_products_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_order_products_train.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
# Orders and customer split
df_orders.groupby("eval_set").nunique()
# Out:
#           order_id  user_id  eval_set  order_number  order_dow  \
# eval_set
# prior      3214874   206209         1            99          7
# test         75000    75000         1            97          7
# train       131209   131209         1            97          7
#
#           order_hour_of_day  days_since_prior_order
# eval_set
# prior                    24                      31
# test                     24                      31
# train                    24                      31

# %%
user_order_count = df_orders.groupby("user_id")["order_number"].aggregate(max).reset_index().order_number.value_counts()

plt.figure(figsize=(15,8))
plt.bar(user_order_count.index, user_order_count.values, alpha=0.8)
plt.ylabel("Frequency", fontsize=15)
plt.xlabel("Orders per user", fontsize=15)
plt.show()

# %%
# Observe the long tail phenomenon

order_product_count = df_order_products_train.groupby("order_id")["add_to_cart_order"].aggregate(max).reset_index().add_to_cart_order.value_counts()

plt.figure(figsize=(15,8))
plt.bar(order_product_count.index, order_product_count.values, alpha=0.8)
plt.ylabel('Frequency', fontsize=15)
plt.xlabel('Products per order', fontsize=15)
plt.show()

# %%
color = sns.color_palette("pastel")

plt.figure(figsize=(15,8))
sns.countplot(x="order_dow", data=df_orders, color=color[2])
# plt.ylabel('Count', fontsize=12)
# plt.xlabel('Day of week', fontsize=12)
# plt.xticks(rotation='vertical')
# plt.title("Frequency of order by week day", fontsize=15)
plt.show()
